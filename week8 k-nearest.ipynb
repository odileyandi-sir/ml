# %%
import numpy as np

import pandas as pd

from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics


names=['sepal-length','sepal-width','petal-length','petal-width','Class'] #Readdatasettopandasdataframe

dataset=pd.read_csv("C:/Users/Jeevan/Downloads/iris2.csv",names=names)

X=dataset.iloc[:,:-1]

y=dataset.iloc[:,-1]

print(X.head())

Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3)
classifier=KNeighborsClassifier(n_neighbors=5).fit(Xtrain,ytrain)

ypred=classifier.predict(Xtest)

i=0

print("\n	-")

print('%-25s%-25s%-25s'%('OriginalLabel','PredictedLabel','Corect/Wrong'))

print("	-")

for label in ytest:

        print('%-25s%-25s'%(label,ypred[i]),end="")

        if(label==ypred[i]):

            print('%-25s'%('Correct'))

        else:

            print('%-25s'%('Wrong'))



i=i+1

print("	-")

print("\nConfusionMatrix:\n",metrics.confusion_matrix(ytest,ypred))

print("	-")

print("\nClassificationReport:\n",metrics.classification_report(ytest,ypred))

print("	-")

print('Accuracyoftheclassiferis%0.2f'%metrics.accuracy_score(ytest,ypred))
# Out:
#    sepal-length  sepal-width  petal-length  petal-width
# 1           5.1          3.5           1.4          0.2
# 2           4.9          3.0           1.4          0.2
# 3           4.7          3.2           1.3          0.2
# 4           4.6          3.1           1.5          0.2
# 5           5.0          3.6           1.4          0.2
#
# 	-
# OriginalLabel            PredictedLabel           Corect/Wrong
# 	-
# Iris-setosa              Iris-setosa              Correct
# Iris-setosa              Iris-setosa              Correct
# Iris-setosa              Iris-setosa              Correct
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-virginica           Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-setosa              Iris-setosa              Correct
# Iris-setosa              Iris-setosa              Correct
# Iris-setosa              Iris-setosa              Correct
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-virginica           Iris-setosa              Wrong
# Iris-setosa              Iris-setosa              Correct
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-versicolor          Iris-setosa              Wrong
# Iris-virginica           Iris-setosa              Wrong
# 	-
#
# ConfusionMatrix:
#  [[12  0  0]
#  [ 0 17  0]
#  [ 0  1 15]]
# 	-
#
# ClassificationReport:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.94      1.00      0.97        17
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# 	-
# Accuracyoftheclassiferis0.98
